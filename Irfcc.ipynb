# %%
# %matplotlib notebook
from lmfit import Parameters
param = Parameters()

# %%
path1 = "//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/feff_amp_phases/77_Ir_L3/"
path2 = "//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/Demo/"

# %%
feff_files = [f for f in sorted(glob.glob(path1+"Irfcc*.dat"))][:2]
# feff_files = [f for f in sorted(glob.glob(path1+"bccFe_cus*.dat"))][:]
feff_files += sorted(glob.glob(path1+"Irfcc*.dat"))[3:4]
feff_files += sorted(glob.glob(path1+"Irfcc*.dat"))[5:6]
# feff_files += sorted(glob.glob(path1+"bccFe_[!391]*.dat"))[2:]
# feff_files.append(glob.glob(path1+"Co_N*ZnS*.dat")[0])
# feff_files.append(sorted(glob.glob(path1+"*hcp_Co.dat"))[3])
# feff_files.append(sorted(glob.glob(path1+"*hcp_Co.dat"))[4])

for f in feff_files:
    print(f[len(path1):])
# Out:
# Irfcc_272_12_Ir_Ir.dat
# Irfcc_385_6_Ir_Ir.dat
# Irfcc_472_24_Ir_Ir.dat
# Irfcc_545_12_Ir_Ir_Ir_Ir.dat

# %%
for i, ffile in enumerate(feff_files):
    _, par = readfeff(ffile)
    if i == 0:
        print(f"param.clear()")
        print(f"#{ffile[len(path1):]}")
        print(f"param.add('R{i:d}', value={par[2]:.2f}, min={par[2]*.95:.2f}, max={par[2]*1.05:.2f}, vary=True)")
        print(f"param.add('N{i:d}', value={par[1]:.1f}, min={par[1]*.9:.1f}, max={par[1]*1.1:.1f}, vary=True)")
        print(f"param.add('sigma{i:d}', value=0.05, min=0.01, max=0.1, vary=True)")
        print(f"param.add('C3_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('C4_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('DelE0_{i:d}', value=0, min=-20, max=20, vary=True)")
        print(f"param.add('S02_{i:d}', value=0.8, min=0.8, max=1, vary=False)")
    else:
        print(f"#{ffile[len(path1):]}")
        print(f"param.add('R{i:d}', value={par[2]:.2f}, min={par[2]*.95:.2f}, max={par[2]*1.05:.2f}, vary=True)")
        print(f"param.add('N{i:d}', value={par[1]:.1f}, min={par[1]*.9:.1f}, max={par[1]*1.1:.1f}, vary=True)")
        print(f"param.add('sigma{i:d}', value=0.05, min=0.01, max=0.1, vary=True, expr='sigma{i-1:d}')")
        print(f"param.add('C3_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('C4_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('DelE0_{i:d}', value=0, min=-20, max=20, vary=True, expr='DelE0_0')")
        print(f"param.add('S02_{i:d}', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')")
    print("\n")
# Out:
# param.clear()
# #Irfcc_272_12_Ir_Ir.dat
# param.add('R0', value=2.73, min=2.59, max=2.86, vary=True)
# param.add('N0', value=12.0, min=10.8, max=13.2, vary=True)
# param.add('sigma0', value=0.05, min=0.01, max=0.1, vary=True)
# param.add('C3_0', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_0', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_0', value=0, min=-20, max=20, vary=True)
# param.add('S02_0', value=0.8, min=0.8, max=1, vary=False)
#
#
# #Irfcc_385_6_Ir_Ir.dat
# param.add('R1', value=3.85, min=3.66, max=4.05, vary=True)
# param.add('N1', value=6.0, min=5.4, max=6.6, vary=True)
# param.add('sigma1', value=0.05, min=0.01, max=0.1, vary=True, expr='sigma0')
# param.add('C3_1', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_1', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_1', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_1', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')
#
#
# #Irfcc_472_24_Ir_Ir.dat
# param.add('R2', value=4.72, min=4.48, max=4.96, vary=True)
# param.add('N2', value=24.0, min=21.6, max=26.4, vary=True)
# param.add('sigma2', value=0.05, min=0.01, max=0.1, vary=True, expr='sigma1')
# param.add('C3_2', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_2', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_2', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_2', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')
#
#
# #Irfcc_545_12_Ir_Ir_Ir_Ir.dat
# param.add('R3', value=5.45, min=5.18, max=5.72, vary=True)
# param.add('N3', value=12.0, min=10.8, max=13.2, vary=True)
# param.add('sigma3', value=0.05, min=0.01, max=0.1, vary=True, expr='sigma2')
# param.add('C3_3', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_3', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_3', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_3', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')

# %%
param.clear()
#Irfcc_272_12_Ir_Ir.dat
param.add('R0', value=2.73, min=2.59, max=2.86, vary=True)
param.add('N0', value=12.0, min=10.8, max=13.2, vary=False)
param.add('sigma0', value=0.05, min=0.01, max=0.1, vary=True)
param.add('C3_0', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_0', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_0', value=0, min=-20, max=20, vary=True)
param.add('S02_0', value=0.8, min=0.8, max=1, vary=False)


#Irfcc_385_6_Ir_Ir.dat
param.add('R1', value=3.85, min=3.66, max=4.05, vary=True)
param.add('N1', value=6.0, min=5.4, max=6.6, vary=False)
param.add('sigma1', value=0.05, min=0.01, max=0.1, vary=True, expr='sigma0')
param.add('C3_1', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_1', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_1', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_1', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')


#Irfcc_472_24_Ir_Ir.dat
param.add('R2', value=4.7, min=4.48, max=4.96, vary=True)
param.add('N2', value=24.0, min=21.6, max=26.4, vary=False)
param.add('sigma2', value=0.05, min=0.01, max=0.2, vary=True)
param.add('C3_2', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_2', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_2', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_2', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')

#Irfcc_545_12_Ir_Ir_Ir_Ir.dat
param.add('R3', value=5.42, min=5.18, max=5.72, vary=True)
param.add('N3', value=12.0, min=10.8, max=13.2, vary=True)
param.add('sigma3', value=0.05, min=0.01, max=0.2, vary=True)
param.add('C3_3', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_3', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_3', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_3', value=0.8, min=0.8, max=1, vary=False, expr='S02_0')

# %%
data_file = [f for f in sorted(glob.glob(path2+"Ir_L3*.chik"))]
data_file
# Out:
# ['//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/Demo/Ir_L3_calib.chik']

# %%
col_names = ['k', 'chi', 'chik', 'chik2', 'chik3', 'win', 'energy']
dat = pd.read_csv(data_file[0], comment='#', sep='\s+', names=col_names)

# %%
from lmfit import minimize

fit_range = [3.15, 18]
out = minimize(residual, param, method='leastsq', args=(dat['k'], dat['chik2'], fit_range, feff_files, 2))

# %%
out
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>222</td><td></td></tr><tr><td># data points</td><td>297</td><td></td></tr><tr><td># variables</td><td>9</td><td></td></tr><tr><td>chi-square</td><td> 16.7786774</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.05825930</td><td></td></tr><tr><td>Akaike info crit.</td><td>-835.466109</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-802.222520</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> R0 </td><td>  2.70595368 </td><td>  8.6405e-04 </td><td> (0.03%) </td><td> 2.73 </td><td>  2.59000000 </td><td>  2.86000000 </td><td> True </td><td>  </td></tr><tr><td> N0 </td><td>  12.0000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 12.0 </td><td>  10.8000000 </td><td>  13.2000000 </td><td> False </td><td>  </td></tr><tr><td> sigma0 </td><td>  0.05939174 </td><td>  3.7359e-04 </td><td> (0.63%) </td><td> 0.05 </td><td>  0.01000000 </td><td>  0.10000000 </td><td> True </td><td>  </td></tr><tr><td> C3_0 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_0 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_0 </td><td>  4.84060660 </td><td>  0.26800517 </td><td> (5.54%) </td><td> 0 </td><td> -20.0000000 </td><td>  20.0000000 </td><td> True </td><td>  </td></tr><tr><td> S02_0 </td><td>  0.80000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.8 </td><td>  0.80000000 </td><td>  1.00000000 </td><td> False </td><td>  </td></tr><tr><td> R1 </td><td>  3.82570918 </td><td>  0.00301869 </td><td> (0.08%) </td><td> 3.85 </td><td>  3.66000000 </td><td>  4.05000000 </td><td> True </td><td>  </td></tr><tr><td> N1 </td><td>  6.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 6.0 </td><td>  5.40000000 </td><td>  6.60000000 </td><td> False </td><td>  </td></tr><tr><td> sigma1 </td><td>  0.05939174 </td><td>  3.7359e-04 </td><td> (0.63%) </td><td> 0.05 </td><td>  0.01000000 </td><td>  0.10000000 </td><td> False </td><td> sigma0 </td></tr><tr><td> C3_1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_1 </td><td>  4.84060660 </td><td>  0.26800517 </td><td> (5.54%) </td><td> 0 </td><td> -20.0000000 </td><td>  20.0000000 </td><td> False </td><td> DelE0_0 </td></tr><tr><td> S02_1 </td><td>  0.80000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.8 </td><td>  0.80000000 </td><td>  1.00000000 </td><td> False </td><td> S02_0 </td></tr><tr><td> R2 </td><td>  4.70364452 </td><td>  0.00235088 </td><td> (0.05%) </td><td> 4.7 </td><td>  4.48000000 </td><td>  4.96000000 </td><td> True </td><td>  </td></tr><tr><td> N2 </td><td>  24.0000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 24.0 </td><td>  21.6000000 </td><td>  26.4000000 </td><td> False </td><td>  </td></tr><tr><td> sigma2 </td><td>  0.07019316 </td><td>  0.00110055 </td><td> (1.57%) </td><td> 0.05 </td><td>  0.01000000 </td><td>  0.20000000 </td><td> True </td><td>  </td></tr><tr><td> C3_2 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_2 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_2 </td><td>  4.84060660 </td><td>  0.26800517 </td><td> (5.54%) </td ...

# %%
#Quick plot chi(k)
#Quick plot chi(k)
exafs_fit = calculate_exafs_lmfit(dat.k, out.params, feff_files, None, 2)
fig, ax = plt.subplots(1,2, sharey=False, figsize=(8,4))
kmin = fit_range[0]
kmax = fit_range[1]

ax[0].plot(dat.k, dat.chik2, 'b')
ax[0].plot(dat.k, exafs_fit, 'r')
ax[0].set_xlim(kmin,kmax)
ax[0].axhline(0, color='black')


test = Group()
xftf(dat.k, dat.chik2, group=test, kweight=0, window='sine', kmin=kmin, kmax=kmax)
fit = Group()
xftf(dat.k, np.nan_to_num(exafs_fit), group=fit, kweight=0, window='sine', kmin=kmin, kmax=kmax)


ax[1].plot(test.r, test.chir_mag, 'blue')
ax[1].plot(test.r, test.chir_re, 'blue')
ax[1].plot(fit.r, fit.chir_mag, 'r')
ax[1].plot(fit.r, fit.chir_re, 'r')
ax[1].plot(fit.r, abs(test.chir_mag-fit.chir_mag), 'black')
ax[1].axhline(0, color='black')
ax[1].set_xlim(0.5,5.9)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.6333333333333">

# %%
print(data_file[0][len(path2):-24])
file_name = data_file[0][len(path2):-24]

# %%
save_data_files(file_name, out, path2, feff_files, data_file[0], dat.k, dat.chi, k_weight = 2,
                    k_min=3, k_max=14)
