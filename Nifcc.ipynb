# %%
# %matplotlib notebook
from lmfit import Parameters
param = Parameters()

# %%
path1 = "//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/feff_amp_phases/28_Ni_K/"
path2 = "//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/Demo/"

# %%
feff_files = [f for f in sorted(glob.glob(path1+"Nifcc*.dat"))][:2]
# feff_files = [f for f in sorted(glob.glob(path1+"bccFe_cus*.dat"))][:]
feff_files += sorted(glob.glob(path1+"Nifcc*.dat"))[3:4]
feff_files += sorted(glob.glob(path1+"Nifcc*.dat"))[5:6]
# feff_files += sorted(glob.glob(path1+"bccFe_[!391]*.dat"))[2:]
# feff_files.append(glob.glob(path1+"Co_N*ZnS*.dat")[0])
# feff_files.append(sorted(glob.glob(path1+"*hcp_Co.dat"))[3])
# feff_files.append(sorted(glob.glob(path1+"*hcp_Co.dat"))[4])

for f in feff_files:
    print(f[len(path1):])
# Out:
# Nifcc_245_12_Ni_Ni.dat
# Nifcc_347_6_Ni_Ni.dat
# Nifcc_425_24_Ni_Ni.dat
# Nifcc_491_24_Ni_Ni_Ni.dat

# %%
for i, ffile in enumerate(feff_files):
    _, par = readfeff(ffile)
    if i == 0:
        print(f"param.clear()")
        print(f"#{ffile[len(path1):]}")
        print(f"param.add('R{i:d}', value={par[2]:.2f}, min={par[2]*.95:.2f}, max={par[2]*1.05:.2f}, vary=True)")
        print(f"param.add('N{i:d}', value={par[1]:.1f}, min={par[1]*.9:.1f}, max={par[1]*1.1:.1f}, vary=False)")
        print(f"param.add('sigma{i:d}', value=0.05, min=0.01, max=0.2, vary=True)")
        print(f"param.add('C3_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('C4_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('DelE0_{i:d}', value=0, min=-20, max=20, vary=True)")
        print(f"param.add('S02_{i:d}', value=0.93, min=0.8, max=1, vary=False)")
    else:
        print(f"#{ffile[len(path1):]}")
        print(f"param.add('R{i:d}', value={par[2]:.2f}, min={par[2]*.95:.2f}, max={par[2]*1.05:.2f}, vary=True)")
        print(f"param.add('N{i:d}', value={par[1]:.1f}, min={par[1]*.9:.1f}, max={par[1]*1.1:.1f}, vary=False)")
        print(f"param.add('sigma{i:d}', value=0.05, min=0.01, max=0.2, vary=True, expr='sigma{i-1:d}')")
        print(f"param.add('C3_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('C4_{i:d}', value=0, min=0.000, max=0.02, vary=False)")
        print(f"param.add('DelE0_{i:d}', value=0, min=-20, max=20, vary=True, expr='DelE0_0')")
        print(f"param.add('S02_{i:d}', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')")
    print("\n")
# Out:
# param.clear()
# #Nifcc_245_12_Ni_Ni.dat
# param.add('R0', value=2.46, min=2.33, max=2.58, vary=True)
# param.add('N0', value=12.0, min=10.8, max=13.2, vary=False)
# param.add('sigma0', value=0.05, min=0.01, max=0.2, vary=True)
# param.add('C3_0', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_0', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_0', value=0, min=-20, max=20, vary=True)
# param.add('S02_0', value=0.93, min=0.8, max=1, vary=False)
#
#
# #Nifcc_347_6_Ni_Ni.dat
# param.add('R1', value=3.48, min=3.30, max=3.65, vary=True)
# param.add('N1', value=6.0, min=5.4, max=6.6, vary=False)
# param.add('sigma1', value=0.05, min=0.01, max=0.2, vary=True, expr='sigma0')
# param.add('C3_1', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_1', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_1', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_1', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')
#
#
# #Nifcc_425_24_Ni_Ni.dat
# param.add('R2', value=4.26, min=4.04, max=4.47, vary=True)
# param.add('N2', value=24.0, min=21.6, max=26.4, vary=False)
# param.add('sigma2', value=0.05, min=0.01, max=0.2, vary=True, expr='sigma1')
# param.add('C3_2', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_2', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_2', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_2', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')
#
#
# #Nifcc_491_24_Ni_Ni_Ni.dat
# param.add('R3', value=4.91, min=4.67, max=5.16, vary=True)
# param.add('N3', value=24.0, min=21.6, max=26.4, vary=False)
# param.add('sigma3', value=0.05, min=0.01, max=0.2, vary=True, expr='sigma2')
# param.add('C3_3', value=0, min=0.000, max=0.02, vary=False)
# param.add('C4_3', value=0, min=0.000, max=0.02, vary=False)
# param.add('DelE0_3', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
# param.add('S02_3', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')

# %%
param.clear()
#Nifcc_245_12_Ni_Ni.dat
param.add('R0', value=2.477, min=2.33, max=2.58, vary=False)
param.add('N0', value=12.0, min=10.8, max=13.2, vary=False)
param.add('sigma0', value=0.085, min=0.01, max=0.2, vary=False)
param.add('C3_0', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_0', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_0', value=0, min=-20, max=20, vary=True)
param.add('S02_0', value=0.93, min=0.8, max=1, vary=False)


#Nifcc_347_6_Ni_Ni.dat
param.add('R1', value=3.48, min=3.30, max=3.65, vary=True)
param.add('N1', value=6.0, min=5.4, max=6.6, vary=False)
param.add('sigma1', value=0.05, min=0.01, max=0.2, vary=True, expr='sigma0')
param.add('C3_1', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_1', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_1', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_1', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')

#Nifcc_425_24_Ni_Ni.dat
param.add('R2', value=4.26, min=4.04, max=4.47, vary=True)
param.add('N2', value=24.0, min=21.6, max=26.4, vary=True)
param.add('sigma2', value=0.05, min=0.01, max=0.3, vary=True)
param.add('C3_2', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_2', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_2', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_2', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')

#Nifcc_491_24_Ni_Ni_Ni.dat
param.add('R3', value=4.91, min=4.67, max=5.16, vary=True)
param.add('N3', value=24.0, min=21.6, max=26.4, vary=True)
param.add('sigma3', value=0.05, min=0.01, max=0.3, vary=True)
param.add('C3_3', value=0, min=0.000, max=0.02, vary=False)
param.add('C4_3', value=0, min=0.000, max=0.02, vary=False)
param.add('DelE0_3', value=0, min=-20, max=20, vary=True, expr='DelE0_0')
param.add('S02_3', value=0.93, min=0.8, max=1, vary=False, expr='S02_0')

# %%
data_file = [f for f in sorted(glob.glob(path2+"Ni*.chik"))]
data_file
# Out:
# ['//Users/akhiltayal/Library/CloudStorage/GoogleDrive-akhil.tayal.bnl@gmail.com/My Drive/Demo/Ni_foil.chik']

# %%
col_names = ['k', 'chi', 'chik', 'chik2', 'chik3', 'win', 'energy']
dat = pd.read_csv(data_file[0], comment='#', sep='\s+', names=col_names)

# %%
from lmfit import minimize

fit_range = [2.9, 15.5]
out = minimize(residual, param, method='leastsq', args=(dat['k'], dat['chik2'], fit_range, feff_files, 2))

# %%
out
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>327</td><td></td></tr><tr><td># data points</td><td>252</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 17.9405821</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.07352698</td><td></td></tr><tr><td>Akaike info crit.</td><td>-649.875673</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-621.640241</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> R0 </td><td>  2.47700000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 2.477 </td><td>  2.33000000 </td><td>  2.58000000 </td><td> False </td><td>  </td></tr><tr><td> N0 </td><td>  12.0000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 12.0 </td><td>  10.8000000 </td><td>  13.2000000 </td><td> False </td><td>  </td></tr><tr><td> sigma0 </td><td>  0.08500000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.085 </td><td>  0.01000000 </td><td>  0.20000000 </td><td> False </td><td>  </td></tr><tr><td> C3_0 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_0 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_0 </td><td>  2.50407092 </td><td>  0.13740597 </td><td> (5.49%) </td><td> 0 </td><td> -20.0000000 </td><td>  20.0000000 </td><td> True </td><td>  </td></tr><tr><td> S02_0 </td><td>  0.93000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.93 </td><td>  0.80000000 </td><td>  1.00000000 </td><td> False </td><td>  </td></tr><tr><td> R1 </td><td>  3.49315831 </td><td>  0.00440769 </td><td> (0.13%) </td><td> 3.48 </td><td>  3.30000000 </td><td>  3.65000000 </td><td> True </td><td>  </td></tr><tr><td> N1 </td><td>  6.00000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 6.0 </td><td>  5.40000000 </td><td>  6.60000000 </td><td> False </td><td>  </td></tr><tr><td> sigma1 </td><td>  0.08500000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.085 </td><td>  0.01000000 </td><td>  0.20000000 </td><td> False </td><td> sigma0 </td></tr><tr><td> C3_1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_1 </td><td>  2.50407092 </td><td>  0.13740597 </td><td> (5.49%) </td><td> 0 </td><td> -20.0000000 </td><td>  20.0000000 </td><td> False </td><td> DelE0_0 </td></tr><tr><td> S02_1 </td><td>  0.93000000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 0.93 </td><td>  0.80000000 </td><td>  1.00000000 </td><td> False </td><td> S02_0 </td></tr><tr><td> R2 </td><td>  4.33684535 </td><td>  0.00299771 </td><td> (0.07%) </td><td> 4.26 </td><td>  4.04000000 </td><td>  4.47000000 </td><td> True </td><td>  </td></tr><tr><td> N2 </td><td>  26.3999999 </td><td>  2.87213294 </td><td> (10.88%) </td><td> 24.0 </td><td>  21.6000000 </td><td>  26.4000000 </td><td> True </td><td>  </td></tr><tr><td> sigma2 </td><td>  0.09991085 </td><td>  0.00396143 </td><td> (3.96%) </td><td> 0.05 </td><td>  0.01000000 </td><td>  0.30000000 </td><td> True </td><td>  </td></tr><tr><td> C3_2 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> C4_2 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>  0.02000000 </td><td> False </td><td>  </td></tr><tr><td> DelE0_2 </td><td>  2.50407092 </td><td>  0.13740597 </td><td> (5.4 ...

# %%
#Quick plot chi(k)
#Quick plot chi(k)
exafs_fit = calculate_exafs_lmfit(dat.k, out.params, feff_files, None, 2)
fig, ax = plt.subplots(1,2, sharey=False, figsize=(8,4))
kmin = fit_range[0]
kmax = fit_range[1]

ax[0].plot(dat.k, dat.chik2, 'b')
ax[0].plot(dat.k, exafs_fit, 'r')
ax[0].set_xlim(kmin,kmax)
ax[0].axhline(0, color='black')


test = Group()
xftf(dat.k, dat.chik2, group=test, kweight=0, window='sine', kmin=kmin, kmax=kmax)
fit = Group()
xftf(dat.k, np.nan_to_num(exafs_fit), group=fit, kweight=0, window='sine', kmin=kmin, kmax=kmax)


ax[1].plot(test.r, test.chir_mag, 'blue')
ax[1].plot(test.r, test.chir_re, 'blue')
ax[1].plot(fit.r, fit.chir_mag, 'r')
ax[1].plot(fit.r, fit.chir_re, 'r')
ax[1].plot(fit.r, abs(test.chir_mag-fit.chir_mag), 'black')
ax[1].axhline(0, color='black')
ax[1].set_xlim(0.5,5.9)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800.0166666666667">

# %%
print(data_file[0][len(path2):-24])
file_name = data_file[0][len(path2):-24]

# %%
save_data_files(file_name, out, path2, feff_files, data_file[0], dat.k, dat.chi, k_weight = 2,
                    k_min=3, k_max=14)
